# %%
import numpy as np

# %% [markdown]
# The Basic

# %%
a = np.array([1,2,3])
print(a)
# Out:
# [1 2 3]

# %%
b = np.array([[9.0,8.0,7.0],[6.0,5.0,4.0]])
print(b)
# Out:
# [[9. 8. 7.]
#  [6. 5. 4.]]

# %%
# Get Dimension
a.ndim
# Out:
# 1

# %%
# Get Shape
# a.shape
b.shape
# Out:
# (2, 3)

# %%
# Get Type
a.dtype
# Out:
# dtype('int64')

# %%
# Get Size
a.itemsize
# Out:
# 8

# %%
# Get total size
#a.size * a.itemsize
a.nbytes
# Out:
# 24
